# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset

df = pd.read_csv('hotel_booking.csv', sep = ',')

# %% [markdown]
# # Data Exploration and Data Cleaning

# %%
# Calling the first five rows on the dataset
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
# Calling the last five rows of the dataset
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Checking the total number of rows and columns in the dataset
df.shape
# Out:
# (119390, 36)

# %%
# Checking the columns in the dataset
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
# Summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Converting the date column to datetime format

df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"])
df['reservation_status_date'][:5]
# Out:
# 0   2015-07-01
# 1   2015-07-01
# 2   2015-07-02
# 3   2015-07-02
# 4   2015-07-03
# Name: reservation_status_date, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # EDA

# %%
# Showing descriptive values of strings in the dataset 
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
# Check numerical data summary
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
# Using the for loop function to call on the unique values present in the descriptive object value.

for items in df.describe(include = "object"):
    print(items)
    print(df[items].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
# Checking for the missing values

df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Dropping columns not necessary for this analysis
df.drop(["agent", "company"], axis = 1, inplace = True)

# Dropping all NaN values 
df.dropna(inplace = True)

print(df.isnull().sum())
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# Filtering out extreme values in ADR column

df = df[df['adr']<5000]
df[df['adr']<5000]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # Data Analyzation and Visualizations
# - To carry this out you need to remember your problem statement.
# - Recall that the hotel in question has been experiencing high cancelation rates

# %%
# Checking for the reservation Status.

cancelled_perc = df['is_canceled'].value_counts(normalize = True)
# Visualizing

plt.figure(figsize = (6,4))
plt.title('Reservation Status Count')
plt.bar(['Not Canceled', 'Canceled'], df['is_canceled'].value_counts(), edgecolor ='b', width = 0.7)
plt.show()

# %% [markdown]
# Insight: 60% of the hotel bookings weren't cancelled but 40% were cancelled.

# %%
# Checking Reservation Status of Resort and City Hotel

plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data = df, palette = 'Reds')
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation Status in Different Hotels', size = 20)
plt.xlabel('Hotels')
plt.ylabel('Number of Reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %% [markdown]
# The City Hotel has a higher number of reservations than the Resort Hotel. Both hotels have a significant portion of cancelled reservation, but the City Hotel shows a notably higher number of cancellations than the Resort Hotel. This suggests that the City Hotel may experience more volatility in bookings, possibly indicating different customer behavior patterns or market factors impacting cancellations for city-based accommodations compared to resort locations.

# %% [markdown]
# ## VIsualizing highest cancelled reservations for Resort and City hotels

# %%
# Checking for Not canceled and canceled reservations in Resort Hotel
resort_hotel = df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Summary: 72% of reservations in Resort hotel wasn't canceled but 28% was canceled
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
# Checking for Not canceled and canceled reservations in City Hotel
city_hotel = df[df['hotel']== 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %% [markdown]
# Summary: 58% of reservations in City hotel weren't canceled but 42% were canceled

# %%
# Calculating the mean of Average daily rate (ADR) in respect to reservation status date for both resort and city hotel.

resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

print(resort_hotel)
print(city_hotel)
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-02                 9.633750
# 2015-01-18                 0.000000
# 2015-01-21                37.301209
# ...                             ...
# 2017-09-08               101.012500
# 2017-09-09               147.778333
# 2017-09-10               145.272500
# 2017-09-12               153.570000
# 2017-09-14               105.930000
#
# [913 rows x 1 columns]
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-20                76.500000
# 2015-01-30                61.400000
# 2015-02-17                76.500000
# ...                             ...
# 2017-09-03               137.172600
# 2017-09-04               116.925385
# 2017-09-05               154.000000
# 2017-09-06                93.293333
# 2017-09-07               159.685000
#
# ...

# %%
# plotting the Average Daily Rate of City and Resort Hotel

plt.figure(figsize = (20,8))
plt.title('Average Daily Rate of City and Resort Hotel Over the Years', fontsize = 20)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# This chart compares the Average Daily Rate (ADR) of Resort Hotels and City Hotels from 2014 to 2017. Resort Hotels typically exhibit higher ADRs than City Hotels during peak periods, such as holidays or vacation seasons, with noticeable variability marked by sharp peaks and dips due to seasonal tourism demand. In contrast, City Hotels maintain a more stable ADR, with minor seasonal fluctuations, likely catering to business travel

# %%
# Checking monthly reservation status and months with highest cancellation

df['month'] = df['reservation_status_date'].dt.month
# Plotting
plt.figure(figsize = (16,8))
ax1 = sns.countplot(x = 'month', hue = 'is_canceled', data = df, palette = 'dark')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor = (1,1))
plt.title('Reservation Status Per Month', size = 20)
plt.xlabel('Months')
plt.ylabel('Number of reservations')
plt.legend(['Not canceled', 'canceled'])
plt.show()
# The chart below shows that when there is less cancellations, the reservations are maximum and when the reseravation are less the cancellations are maximum

# %% [markdown]
# This chart shows reservation trends per month, with **not canceled bookings** consistently higher than **canceled bookings**. **July and August** have the highest reservations, reflecting peak travel seasons, but also higher cancellations. **December to February** see fewer reservations overall, aligning with the off-peak season. Higher cancellations during busy months may result from overbooking or travel plan changes.

# %%
# Plotting the Average Daily Rate for each month
plt.figure(figsize = (15,8))
plt.title('Average Daily Rate Per Month', fontsize = 30)
# Filtering the DataFrame (df) to include only rows where the value in the 'is_canceled' column is equal to 1.
sns.barplot(x = 'month', y = 'adr', data = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %% [markdown]
# This chart shows the Average Daily Rate (ADR) per month, with January and July having the highest rates due to peak holiday seasons, while ADRs drop from August to December, reflecting off-peak demand.

# %%
# Checking the top 10 countries with highest cancelled reservations

cancelled_data = df[df['is_canceled'] == 1]
top_10_countries = cancelled_data['country'].value_counts()[:10]
# Plotting
plt.figure(figsize = (8,8))
plt.title('Top 10 Countries with Canceled Reservations')
plt.pie(top_10_countries, autopct = '%.1f%%', labels = top_10_countries.index)
plt.show()

# %% [markdown]
# portugal(prt) has the highest canceled reservation rate more than other countries; followed by great Britain (GBR), Spain (ESP), France (FRA), Italy (ITA), etc

# %%
df[df['is_canceled']==1]['country'].value_counts()[:30]
# Out:
# country
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# CHN      462
# CHE      428
# NLD      387
# CN       254
# RUS      239
# AUT      230
# SWE      227
# POL      215
# AGO      205
# NOR      181
# ISR      169
# ROU      134
# LUX      109
# MAR      109
# DNK      109
# AUS      107
# TUR      102
# HUN       77
# FIN       69
# KOR       55
# Name: count, dtype: int64

# %% [markdown]
# ### Market Segment

# %%
# Checking the number of customers coming from each market segment

df.market_segment.value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
market_segment = df['market_segment'].value_counts(normalize=True)

plt.figure(figsize=(8, 6))
plt.title('Market Segment')
plt.pie(market_segment, autopct='%.1f%%', labels=market_segment.index)
plt.show()

print(market_segment)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %% [markdown]
# This chart shows that most reservation comes from Online Travel Agencies, followed by Offline Travel Agencies/TO, Groups, Direct, Corporate, complementary and lastly Aviation.

# %%
# Checking for cancelled reservations in the market sector

cancelled_reservation = df[df['is_canceled']==1]
cancelled_reservation.market_segment.value_counts()
# Out:
# market_segment
# Online TA        20738
# Groups           12097
# Offline TA/TO     8277
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: count, dtype: int64

# %%
# Checking the percentage count for each unique value  in the market_segment

cancelled_data.market_segment.value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %% [markdown]
# Why are there 47% canceled reservation and 47% not canceled reservation from the Online Travel Agent market segment?
# - Possible reasons could be that the travel agents shows something different online from what customers end up seeing... This could be facilities, prices, etc.
#
# ###### This isn't an actual fact but could be considered

# %%
x = cancelled_df_adr = cancelled_data.groupby('reservation_status_date').adr.mean()
x
# Out:
# reservation_status_date
# 2014-10-17     62.800000
# 2014-11-18      0.000000
# 2015-01-01     62.062779
# 2015-01-02      9.633750
# 2015-01-18      0.000000
#                  ...
# 2017-08-26    178.200000
# 2017-08-27    167.300000
# 2017-08-28     81.416667
# 2017-08-29    144.253333
# 2017-08-31    189.750000
# Name: adr, Length: 902, dtype: float64

# %%
cancelled_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
# Checking the prices of cancelled bookings

cancelled_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_adr = cancelled_adr.reset_index()
cancelled_adr.sort_values('reservation_status_date', inplace =True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

plt.figure(figsize = (20, 6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = ("not cancelled"))
plt.plot(cancelled_adr['reservation_status_date'], cancelled_adr['adr'], label = ('cancelled'))
plt.legend()
plt.show()

# %%
### This chart seems inconsistent

# %%
cancelled_df_adr = cancelled_adr[(cancelled_adr['reservation_status_date'] > '2016') & (cancelled_adr['reservation_status_date'] < '2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016') & (not_cancelled_df_adr['reservation_status_date'] < '2017-09')]

# %%
print(cancelled_df_adr)
# Out:
#     reservation_status_date         adr
# 295              2016-01-02   88.147143
# 296              2016-01-03   93.053810
# 297              2016-01-04   68.428750
# 298              2016-01-05   82.809895
# 299              2016-01-06   76.845820
# ..                      ...         ...
# 897              2017-08-26  178.200000
# 898              2017-08-27  167.300000
# 899              2017-08-28   81.416667
# 900              2017-08-29  144.253333
# 901              2017-08-31  189.750000
#
# [607 rows x 2 columns]

# %%
not_cancelled_df_adr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 608 entries, 185 to 792
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   reservation_status_date  608 non-null    datetime64[ns]
#  1   adr                      608 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.2 KB

# %%
# Re-plotting 

plt.figure(figsize = (20, 6))
plt.title('Average Daily Rate: Cancelled vs Non-cancelled Bookings')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = ('Cancelled'))
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = ('Not cancelled'))
plt.legend()
plt.show()

# %% [markdown]
# This comparison highlights the Average Daily Rate (ADR) trends for cancelled and non-cancelled bookings. Cancelled bookings tend to have higher ADRs with notable fluctuations, whereas non-canceled bookings exhibits more consistent rates.
